# %% [markdown]
# <a href="https://colab.research.google.com/github/daykoliveira/atividade_processual_4_BI/blob/main/atividade_processual_4_BI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
from io import StringIO
import pandas as pd
import requests

url = 'https://pt.wikipedia.org/wiki/Lista_de_faturamento_dos_clubes_de_futebol_brasileiro'

tabela = soup.find_all('table')
tabela = soup.find('span', 'mw-editsection').find_next('table')

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

tabela_io = StringIO(str(tabela))

# %%
df.to_csv('Lista de faturamento dos clubes de futebol brasileiro.csv', index=False)
df= pd.read_csv('Lista de faturamento dos clubes de futebol brasileiro.csv')

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (20, 5)

# %%
df = pd.read_html(tabela_io)[0]
df
# Out:
#     Posição                 Clube             Estado            Faturamento  \
# 0         1              Flamengo     Rio de Janeiro   R$ 1,374 Bilhões [1]
# 1         2           Corinthians          São Paulo   R$ 1,010 Bilhões [2]
# 2         3             Palmeiras          São Paulo   R$ 908,9 Milhões [4]
# 3         4  Athletico Paranaense             Paraná   R$ 898,9 Milhões [3]
# 4         5            Fluminense     Rio de Janeiro    R$ 695,0 Milhões[5]
# 5         6             São Paulo          São Paulo   R$ 680,7 Milhões [6]
# 6         7         Internacional  Rio Grande do Sul    R$ 654,5 Milhões[7]
# 7         8              Botafogo     Rio de Janeiro    R$ 570,0 Milhões[8]
# 8         9   Red Bull Bragantino          São Paulo    R$ 488,2 Milhões[9]
# 9        10                Grêmio  Rio Grande do Sul  R$ 454,0 Milhões [10]
# 10       11                Santos          São Paulo   R$ 424,4 Milhões[11]
# ...
